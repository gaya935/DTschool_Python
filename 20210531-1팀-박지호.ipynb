# %%
#존재하는 물건 - 개수 추가, 아니면 딕셔너리 추가
d_li = {}
#물건이름 : name, 개수 : num
goods = {}
while True:
    product = input('물건이름을 넣어 주세요.: ')
    if product =='':
        break
    number = int(input('갯수: ')) 
    #goods[product] = number

    if product in goods.keys():
        goods[product] += number
    else:
        goods[product] = number
print(goods)
# 오름차순 정렬
for key, value in sorted(goods.items()):
    print(key, value, end=' ')
# Out:
# 물건이름을 넣어 주세요.: 지우개
# 갯수: 1
# 물건이름을 넣어 주세요.: 연필
# 갯수: 1
# 물건이름을 넣어 주세요.: 과자
# 갯수: 1
# 물건이름을 넣어 주세요.:
# {'지우개': 1, '연필': 1, '과자': 1}
# 과자 1 연필 1 지우개 1

# %%
#단어장 만들기
voca = {}
while True:
    eng = input('eng:')
    if eng == '':
        break
    kor = input('kor: ')
    voca[eng] = kor

print(voca)

# %% [markdown]
# 집합(set)
#
# 1.  자료들이 순서와 중복 없이 저장된 것
# 2.  중괄호{} 안에 요소를 쉼표로 구분하여 나열한다.

# %%
#Set_name = { value1, value2, ..., }
# 집합명 = {요소1, 요소2, ... 요소N}
# 집합명 = set([요소1,요소2,... 요소N])

set_wish = {'새우깡','오감자','양파링','포카칩','양파링'}
set_wish

# %%
set_wish = set(['새우깡','오감자','양파링','포카칩','양파링'])
set_wish

# %%
set_hello = set("Hello")
set_hello

# %% [markdown]
# 집합(set)>요소추출
#
#
# 1.   집합 자료형은 순서가 없기 때문에 인덱싱으로 값을 얻을 수 없다. 집합 자료형에 저장된 값을 인덱싱으로 접근하려면 리스트나 튜플로 변환하여 사용한다.

# %%
set_wish = {'새우깡','오감자','양파링','포카칩','양파링'}
list_siwh = list(set_wish)
print(list_siwh)
print(list_siwh[2])

# %%
set_wish = {'새우깡','오감자','양파링','포카칩','양파링'}
list_siwh = tuple(set_wish)
print(list_siwh)
print(list_siwh[2])

# %% [markdown]
# 집합>연산

# %%
sweety = {'chocolate', 'jelly', 'caramel'}
salty = {'potatochip', 'honeybutterchip', 'chichenpop', 'caramel'}

# 합집합 a|b
print(sweety.union(salty))
print(sweety|salty)

# 교집합 a&b
print(sweety.intersection(salty))
print(sweety&salty)

# 차집합
print(sweety.difference(salty))
print(sweety-salty)
print(salty.difference(sweety))
print(salty-sweety)

# %%
#집합(set)>요소추가
#집합명.add(요소)
set_wish = {'새우깡','오감자','양파링','포카칩','양파링'}
set_wish.add('허니버터')
set_wish

# %%
#집합(set)>요소삭제
#집합명.remove(요소)

set_wish = {'새우깡','오감자','양파링','포카칩','양파링'}
set_wish.remove('오감자')
set_wish

set_wish = {'새우깡','오감자','양파링','포카칩','양파링'}
set_wish.remove('빼빼로')
set_wish

# %%
set_wish = {'새우깡','오감자','양파링','포카칩','양파링'}
if '새우깡' in list(set_wish):
    set_wish.remove('새우깡')
set_wish

# %% [markdown]
# <오류종류>
# *   SyntaxError : 문법이 잘못되었음(오타, 괄호를 제대로 닫지 않았을 때, 콜론(:)을 잘못 사용했을 때 등
# *   TypeError : 타입이 맞지 않음
#
#
# *   ZeroDivisioinError : 0으로 나누기 안됨
# *   IndentationError : 들여쓰기 오류, 줄이 안맞음
#
# *   NameError : 참조변수 없음

# %% [markdown]
# *   순차구조-명령들이 순차적으로 실행되는 구조
#
# *   선택구조-조건에 따라 명령을 선택하여 실행되는 구조
# *   반복구조-동일한 명령이 반복되면서 실행되는 구조

# %% [markdown]
# 코드블록
#
# *  콜론(:) 아랫줄부터 들여쓰기 된 부분을 명령문 블록 또는 코드블록이라고 한다.

# %%
a = 1
if a < 0:
    print('a는 0보다 작다.')
    print('a는 음수이다.')
print('끝')

# %%
a = 1
if a < 0:
    print('a는 0보다 작다.')
print('a는 음수이다.')
print('끝')

# %%
#예제>코로나 자가진단 프로그램 1단계

temp = float(input('체온:'))
if temp > 37.5:
    print('등교불가')

# %%
#if~else구조

a = 5
b = 4
if a % b == 0:
    print(f'{a}는 {b}로 나누어 떨어집니다')
else:
    print(f'')

# %%
temp = float(input('체온:'))
result_wait = input('검사결과대기여부(y/n)')
self_quarantine = input('자각격리여부(y/n)')

if temp > 37.5:
    print('발열기준 초과:등교불가')
elif result_wait == 'y':
    print('검사대기 중 등교불가')
elif self_quarantine == 'y':
    print('자가격리 중 등교불가')
else:
    print('등교가능')

# %%
score = int(input('점수:'))

if 90<=score:
    print('A')
elif 80<=score:
    print('B')
elif 70<= score:
    print('c')
elif 60<= score:
    print('D')
else:
    print('F')

# %%
buy = int(input('물건 구매가를 입력하세요:'))

if 10000<=price>50000:
  
elif 50000<=price>100000:



print(f'구매가:{buy}원')
print(f'할인율:{dc}')

# %%
#예제>최소값 구하기

n1 = int(input("수1:"))
n2 = int(input("수2:"))
n3 = int(input('수3:'))

min_n = min

# %% [markdown]
# 논리연산자
#
# *   항목 추가
# *   항목 추가

# %%
#예제>국립공원 입장료 계산기

age = int(input('나이를 입력하세요:'))
price = 3000
if age > 64 or age <= 7:
    price = 0
elif age >= 8 and age <= 18:
    price = '1000원'
print(f'{price}원 입니다')

# %%
#예제>로그인 프로그램

user_id = 'ID1234'
user_pwd = 'PWD1234'

# 아이디 패스워드 입력
input_id = input('아이디:')
input_pwd = input('패스워드:')

#로그인 처리
if user_id == input_id and user_pwd == input_pwd:
    print('로그인 성공')
else:
    print('로그인 실패')

# %%
#예제>사칙연산프로그램

#입력
num1 = int(input('숫자1: '))
num2 = int(input('숫자2: '))
operator = input('연산기호(+,-,*,/) : ')
result = 0

#처리
if operator=='+':
    result == num1 + num2
elif operator=='-':
    result == num1 - num2
elif operator == '*':
    result = num1 * num2
elif operator == '/':
    if num2 !=0:
        result = num1 / num2
    else:

# %% [markdown]
# 임의의 정수 만들기
#
#
# *   최소부터 최대 사이의 임의의 정수를 리턴한다. (최대도 포함)

# %%
#예제>주사위 던지기 게임
#두 개의 주사위를 던져 더 큰 수가 나오는 사람이 이기는 게임을 작성하시오.

count1 = 0
count2 = 0

for times in range(10):
    dice1 = random.randint(1,6)
    dice2 = random.randint(1,6)
    result = 0
    winner = 0  
    if dice1 > dice2 :
        result = '이겼습니다.'
        winner = 1
        count1 +=1
    elif dice1 < dice2:
        result = '이겼습니다.'
        winner = 2
        count2 +=1
    else: 
        result = '비겼습니다.'
        winner = '1과 주사위2가'
    print(f'{times}번째판은 주사위{winner}이(가) {result} ')

f_winner = 0
f_result = 0
if count1 > count2:
    f_winner = '주사위1'
    f_result = '이겼습니다.'
elif count2 > count1:
    f_winner = '주사위2'
    f_result = '이겼습니다.' 
else:
    f_winner = '둘 다'
    f_result = '비겼습니다.'

print('-'*30)
print(f'주사위1:주사위2 = {count1}: {count2}로 {f_winner}이(가) {f_result}')
